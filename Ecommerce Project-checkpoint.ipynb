# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

# %%
import pandas as pd

dataset = pd.read_csv(r"C:\Users\admin\Desktop\ecoomers project\E-Commerce Sales Analysis.csv", encoding="latin1")

# %%
dataset.head(2)
# Out:
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11-08-2016  11-11-2016  Second Class    CG-12520
# 1       2  CA-2016-152156  11-08-2016  11-11-2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
dataset.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
dataset.shape
# Out:
# (9994, 21)

# %%
dataset.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Year'],
#       dtype='object')

# %%
 dataset['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
x = dataset['Ship Mode'].value_counts().index
y = dataset['Ship Mode'].value_counts().values

# %%
plt.figure(figsize=(5,4))
plt.pie(y,labels=x, startangle=60,autopct="%0.2f%%")
plt.legend(loc=2)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Ship Mode",data=dataset,hue="Category")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Segment",data=dataset)
plt.figtext(0.5, -0.1, 
            "Most orders come from the Consumer segment, followed by Corporate and Home Office segments.", 
            wrap=True, ha="center", fontsize=10)
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.countplot(x="Category", data=dataset, palette="Set2")
plt.title("Orders by Category")

# Short conclusion
plt.figtext(0.5, -0.1, 
            "Office Supplies has the highest number of orders, followed by Technology and Furniture.", 
            wrap=True, ha="center", fontsize=10)

plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16284\267786574.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Category", data=dataset, palette="Set2")

# %%
plt.figure(figsize=(8,4))
sns.countplot(x="Category",data=dataset[dataset['Category']=='Furniture'],hue="Sub-Category")
plt.figtext(0.5, -0.15, 
            "Among Furniture items, some sub-categories like Chairs and Tables dominate the sales.", 
            wrap=True, ha="center", fontsize=10)
plt.show()

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
print(dataset["Order Date"].head())
print(dataset["Order Date"].dtype)
# Out:
# 0    11-08-2016
# 1    11-08-2016
# 2    06-12-2016
# 3    10-11-2015
# 4    10-11-2015
# Name: Order Date, dtype: object
# object

# %%
dataset["Order Date"] = pd.to_datetime(dataset["Order Date"], errors="coerce", dayfirst=True)

# %%
dataset["Year"] = dataset["Order Date"].dt.year
print(dataset[["Order Date", "Year"]].head())
# Out:
#   Order Date    Year
# 0 2016-08-11  2016.0
# 1 2016-08-11  2016.0
# 2 2016-12-06  2016.0
# 3 2015-11-10  2015.0
# 4 2015-11-10  2015.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     4042 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
dataset["Year"].value_counts()
# Out:
# Year
# 2017.0    1322
# 2016.0    1087
# 2015.0     826
# 2014.0     807
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,4))
plt.hist(dataset["Year"], bins=10, edgecolor="Red")
plt.title("Year")
plt.figtext(0.5, -0.1, 
            "Most orders are concentrated around recent years, showing growth over time.", 
            wrap=True, ha="center", fontsize=10)
plt.show()

# %%
sns.barplot(x="Category", y="Profit",data=dataset,estimator="sum")
plt.figtext(0.5, -0.1, 
            "Office Supplies generate the highest total profit, followed by Technology and Furniture.", 
            wrap=True, ha="center", fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dataset["State"].value_counts()[:5]
# Out:
# State
# California      2001
# New York        1128
# Texas            985
# Pennsylvania     587
# Washington       506
# Name: count, dtype: int64

# %%
top_10_state = dataset["State"].value_counts().head(10)
plt.figure(figsize=(12,5))
sns.countplot(
    data=dataset[dataset["State"].isin(top_10_state.index)],
    x="State",
    order=top_10_state.index,
    hue="State",   
    palette="tab10",
    legend=False
)
plt.figtext(0.5, -0.1, 
            "California has the highest orders, followed by Texas and New York, showing strong sales in these states compared to others in the top 10", 
            wrap=True, ha="center", fontsize=10)

plt.show()
